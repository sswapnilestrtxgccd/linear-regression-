# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('salary.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
## lets check how data is vary or depends by using a  graph

# %%
plt.scatter(df['YearsExperience'],df['Salary'], color='r')
plt.title('Experience vs salary')
plt.xlabel('year of experience')
plt.ylabel('salary')
plt.show()

# %%
x=df[['YearsExperience']]
y=df['Salary']

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
import sklearn 
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2 ,random_state=42)

# %%
y_train.shape, y_test.shape
# Out:
# ((24,), (6,))

# %%
x_train.shape, x_test.shape
# Out:
# ((24, 1), (6, 1))

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model.fit(x_train,y_train )
# Out:
# LinearRegression()

# %%
model.coef_ ## y=mx+c
# Out:
# array([9423.81532303])

# %%
model.intercept_
# Out:
# np.float64(25321.583011776813)

# %%
x_train.head(2)
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7

# %%
y_train.head(2)
# Out:
# 28    122391.0
# 24    109431.0
# Name: Salary, dtype: float64

# %%
25321.583011776813+9423.81532303*10.3
#y predicted salary is
# Out:
# 122386.88083898582

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_train)

# %%
x_train.head(2)
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7

# %%
y_train.head(2)
# Out:
# 28    122391.0
# 24    109431.0
# Name: Salary, dtype: float64

# %%
y_train_pred[:2]
# Out:
# array([122386.880839  , 107308.77632215])

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# %%
mean_squared_error(y_train, y_train_pred)
# Out:
# 27102249.73126139

# %%
mean_absolute_error(y_train , y_train_pred)
# Out:
# 4221.046734449738

# %%
round(r2_score(y_train, y_train_pred)*100, 2)
# Out:
# 96.45

# %%
plt.scatter(x, y, color='r')
plt.plot(x, model.predict(x), color='k', lw=3)
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid()
plt.show()

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
model.predict([[10.5]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([124271.6439036])

# %%
model.predict([[10.3]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([122386.880839])
